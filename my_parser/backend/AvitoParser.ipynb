# %%
import parser
import time

import os

from exeptions import FailedItemsGetting, FailedGetRequest
from parser_response import ParserAvito
from request_avito import Url, RequestHandler
from settings import MainSettings

import csv

from bs4 import BeautifulSoup as bs

# %%
settings = MainSettings()

url_obj = parser.get_object_url(settings)

req_avito = RequestHandler()

# %%
html_data = parser.send_get_request(req_avito, url_obj.url)
# Out:
# /home/haimin/PycharmProjects/web_scraping/venv/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.avito.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/haimin/PycharmProjects/web_scraping/venv/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.avito.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
parser_avito = ParserAvito()

parser_avito.html = html_data
total_pages = parser_avito.count_page

# %%
parser.get_main_ads_data(req_avito, 1, url_obj, parser_avito)
# Out:
# 1 https://www.avito.ru/velikiy_novgorod/kvartiry/prodam?pmin=800000&pmax=1200000&p=1
# /home/haimin/PycharmProjects/web_scraping/venv/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.avito.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /home/haimin/PycharmProjects/web_scraping/venv/lib/python3.7/site-packages/urllib3/connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.avito.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
parser_avito.result_data.page_data['Наименование объявления'][7]
# Out:
# '2-к квартира, 56 м², 2/3 эт.'

# %%
parser_avito.result_data.page_data['Url'][7].split('._')[1]
# Out:
# '1318749959'

# %%
obj = {'ad_id':177835542, 'ad_name':'2-к квартира, 44.3 м², 3/5 эт.', 'ad_url':'https://www.avito.ru/velikiy_novgorod/kvartiry/2-k_kvartira_44.3_m_35_et._1978322734', 'ad_price':850000}

# %%
soup = bs(html_data, 'lxml')

# %%
soup.find('a', class_='pagination-page', text='Последняя')
# Out:
# <a class="pagination-page" href="/velikiy_novgorod/kvartiry/prodam-ASgBAgICAUSSA8YQ?p=19&amp;pmax=4000000&amp;pmin=2000000">Последняя</a>

# %%
soup.find('span', class_="snippet-price")
# Out:
# <span class="snippet-price" data-marker="item-price" data-shape="default" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><meta content="RUB" itemprop="priceCurrency"/><meta content="3400000" itemprop="price"/><meta content="https://schema.org/LimitedAvailability" itemprop="availability"/>
#  3 400 000  ₽
#   </span>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script>
#    try {
#  window.firstHiddenTime = document.visibilityState === 'hidden' ? 0 : Infinity;
#  document.addEventListener('visibilitychange', function (event) {
#  window.firstHiddenTime = Math.min(window.firstHiddenTime, event.timeStamp);
#  }, { once: true });
#  if ('PerformanceLongTaskTiming' in window) {
#  var globalStats = window.__statsLongTasks = { tasks: [] };
#  globalStats.observer = new PerformanceObserver(function(list) {
#  globalStats.tasks = globalStats.tasks.concat(list.getEntries());
#  });
#  globalStats.observer.observe({ entryTypes: ['longtask'] });
#  }
#  if (PerformanceObserver && (PerformanceObserver.supportedEntryTypes || []).some(function(e) {
#  return e === 'element'
#  })) {
#  if (!window.oet) {
#  window.oet = [];
#  }
#  new PerformanceObserver(function(l) {
#  window.oet.push.apply(window.oet, l.getEntries());
#  }).observe({ entryTypes: ['element'] });
#  }
#  } catch (e) {
#  console.error(e);
#  }
# ...

# %%
s = '830 000  ₽'
s = s.replace(' ', '')
s
# Out:
# '830000₽'

# %%
int('840 000')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-078b135e21bb> in <module>
# ----> 1 int('840 000')
#
# ValueError: invalid literal for int() with base 10: '840 000'

# %%
type(-100)
# Out:
# int
